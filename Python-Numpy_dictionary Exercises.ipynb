# %% [markdown]
# <a href="https://colab.research.google.com/github/anuvishalp/Python_DataCleaning-Basics/blob/master/Python-Numpy_dictionary%20Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#multilines comment using """ start-end quotes
"""Multiple Ways to Run a Python Program
Let’s assume your file is named:

Code
main.py
Below are all the practical ways to run it.

🟦 1. Run from the Command Line (Most Common)

python main.py

If your system uses python3
python3 main.py

🟩 2. Run by Double‑Clicking (Windows)
If Python is associated with .py files:

Double‑click main.py

It runs in a terminal window
(Not ideal for programs that need input.)

🟨 3. Run Inside an IDE
VS Code
Open folder → open main.py

Click Run ▶️ at the top right
or
Press Ctrl + F5

PyCharm
Right‑click main.py → Run 'main'

IDLE
Open IDLE → File → Open → Run Module (F5)

🟧 4. Run in a Jupyter Notebook / Colab

# %run main.py

Or import it:

python
import main

🟪 5. Run Using Python’s -m Module Mode

If your file is inside a package:

Code
project/
    app/
        __init__.py
        main.py
Run it as a module:

python -m app.main

🟥 6. Run Using exec() (Not common, but valid)

exec(open("main.py").read())

🟫 7. Run Using a Virtual Environment

source venv/bin/activate      # macOS/Linux
venv\Scripts\activate         # Windows

python main.py

🟦 8. Run Using Task Runners (Advanced)
Makefile
Code
run:
    python main.py
Run with:

make run
Invoke
python

# tasks.py
from invoke import task

@task
def run(c):
    c.run("python main.py")
Run with:

invoke run

🟩 9. Run as an Executable Script (Linux/macOS)
Add this to the top of your file:

python
#!/usr/bin/env python3
Make it executable:

chmod +x main.py

Run it:

./main.py

🟨 10. Run Using Docker (Professional Deployment)
Dockerfile

Code
FROM python:3.11
COPY main.py .
CMD ["python", "main.py"]

Build & run:

docker build -t myapp .
docker run myapp """

# %%
#100 days of learning the coding using Python

## DAY-1
1. Write a program that prints "Hello, World!" to the console
2. Add single-line and multi-line comments to your code

Reading List:
1. How does Python compile and run the code?
2. Learn the difference between Python and Java
3. Difference between Compiler and Interpreter

# %%
✅ 1. Program that prints “Hello, World!” with comments
Below is a simple Python script that includes:

A single‑line comment

A multi‑line comment

A correct print statement

python
# This is a single-line comment: the program starts here

"""
This is a multi-line comment.
It explains that the program prints 'Hello, World!' to the console.
"""

print("Hello, World!")
=================

📚 Reading List — Explained Clearly
Here’s a crisp, interview‑ready breakdown of your three study topics.
-----------------------------
1. How does Python compile and run the code?
Python uses a hybrid model:

🔹 Step 1: Your code → Bytecode
Python compiles your .py file into bytecode (a low‑level, platform‑independent representation).

🔹 Step 2: Bytecode → Python Virtual Machine (PVM)
The PVM interprets the bytecode line by line.

🔹 Summary

Python = Compiled to bytecode + Interpreted by PVM

This is why Python feels dynamic and flexible.
--------------------------------
2. Difference between Python and Java

Feature	Python	Java
Typing----Dynamically typed	------------- Statically typed
Syntax---	Very concise	 -----------------Verbose
Speed	----Slower (interpreted)------------	Faster (compiled to JVM bytecode)
Use cases--	AI, ML, scripting, automation--	Enterprise apps, Android, large systems
Learning curve---	Beginner‑friendly---------	More strict, steeper

Quick memory trick
============
Python = flexibility + readability

Java = structure + performance
====================================
3. Difference between Compiler and Interpreter

Concept--------------	Compiler	-------------------Interpreter
Execution	-----Translates entire program at once-----	Executes line by line
Output-------	Machine code / bytecode--------------	Immediate execution
Speed--------	Faster at runtime	-----------------Slower at runtime
Error detection----	Shows all errors after compilation---	Stops at first error
Examples------	C, C++, Java (JVM)---------	Python (PVM), JavaScript

Easy way to remember
==================
Compiler = “Translate the whole book first.”

Interpreter = “Read and act one line at a time.”

# %%
## DAY-2

Create the following variables of different types and print them.
name: String
age: Integer
height: Floating-point number
is_student: Boolean
email: None (representing a null value)
siblings: List
address: Dictionary containing street and city


Reading List:
1. Learn the terms: initialization, declaration and assignment of variables
2. Learn the difference between Dynamically typed and Statically typed variables

# %%
🧪 Python Program: Variables of Different Types
python
# Single-line comment: Creating variables of different data types

"""
Multi-line comment:
This program initializes variables of various types
and prints them to the console.
"""

name = "Anu"                     # String
age = 30                         # Integer
height = 5.4                     # Floating-point number
is_student = False               # Boolean
email = None                     # NoneType (represents null)
siblings = ["Asha", "Ravi"]      # List
address = {                      # Dictionary
    "street": "123 Main St",
    "city": "Bellevue"
}

print(name)
print(age)
print(height)
print(is_student)
print(email)
print(siblings)
print(address)
You can replace the values with your own — the important part is understanding the types.

📚 Reading List — Clear, Interview‑Ready Notes
------------------
1️⃣ Initialization, Declaration, Assignment
Term	Meaning	Python Example

Declaration	Telling the program a variable exists	(Python does this implicitly)

Initialization	Giving a variable its first value	x = 10

Assignment	Giving or updating a value	x = 20

Python twist

Python does not require declaration because it is dynamically typed.

The moment you write x = 10, you have declared + initialized + assigned in one step.

2️⃣ Dynamically Typed vs Statically Typed

Feature	--------------Dynamically Typed (Python)-----------	Statically Typed (Java)
When type is checked	-------At runtime	-------------At compile time
Need to specify type?	-------No-------------	Yes
Flexibility	------------Very high	----------Strict
Example----------	x = 10	-----------int x = 10;

Quick memory trick
=====================
Dynamic = Python = “I’ll figure out the type later.”

Static = Java = “Tell me the type upfront.”

# %%
##Day 3: Input and Output

Basic Input and Output:

Write a program that reads a single input from the user and prints it to the console. For example, if the user enters their name, the program should output: ""Hello, {name}""

Handling Different Data Types:
Extend the program to read and print different types of inputs. Ensure the inputs are properly converted to their respective types and then printed. The program should ask the user to enter:

A string
An integer
A floating-point number

Reading List:
1. Explore various methods for reading different type of inputs
2. Learn about formatting options such as precision, alignment, and decimal places to present output in a clear and concise manner

# %%
🌟 Part 1 — Basic Input & Output
A simple program that reads a name and prints a greeting.

python
name = input("Enter your name: ")
print(f"Hello, {name}")

This is the core idea:
---------------
input() always returns a string

print() displays it
--------------
f"Hello, {name}" is an f‑string, the cleanest way to format output
=======================================
🌟 Part 2 — Handling Different Data Types
Now let’s extend the program to read a string, integer, and float.

python
# Reading a string
text_value = input("Enter a string: ")

# Reading an integer
int_value = int(input("Enter an integer: "))

# Reading a floating-point number
float_value = float(input("Enter a floating-point number: "))

print("\n--- Output ---")
print(f"String value: {text_value}")
print(f"Integer value: {int_value}")
print(f"Float value: {float_value}")
=============================
✔ What this teaches you

input() → always string

int() → converts to integer

float() → converts to decimal

f‑strings → clean formatting
===============================
🌟 Bonus: Formatting Output (Precision, Alignment, Decimal Places)
Here are some examples you can try:

🎯 Decimal places
python
print(f"Float (2 decimal places): {float_value:.2f}")
🎯 Alignment
python
print(f"Left aligned : {text_value:<10}")
print(f"Right aligned: {text_value:>10}")
print(f"Centered     : {text_value:^10}")
🎯 Formatted numbers
python
print(f"Integer with commas: {int_value:,}")
📚 Reading List — Clear, Beginner-Friendly Notes
1️⃣ Explore methods for reading different types of input
input() → always returns string

Convert using:

int()

float()

bool() (careful: "True" becomes True, "false" becomes False)

Use .split() to read multiple values at once
Example:

python
a, b = input("Enter two numbers: ").split()
2️⃣ Learn formatting options (precision, alignment, decimal places)
Focus on:

f‑strings → modern, clean, recommended

format() method

% formatting (older, still useful to recognize)

Examples to explore:

{value:.2f} → 2 decimal places

{value:>10} → right align in 10 spaces

{value:^10} → center align

{value:,} → number with commas

# %%
##Day 4: Basic Operators and Expressions
Arithmetic Operators

Write a program to perform the following arithmetic operations using two numbers:

Addition (+)
Subtraction (-)
Multiplication (*)
Division (/)
Floor Division (//)
Modulus (%)
Exponentiation (**)


Relational Operators

Write a program to compare two numbers using the following operators:
Equal to (==)
Not equal to (!=)
Greater than (>)
Less than (<)
Greater than or equal to (>=)
Less than or equal to (<=)


Logical Operators

Write a program that evaluates the following between 2 booleans(True or False):
Logical AND (and)
Logical OR (or)
Logical NOT (not)

# %%
##🧮 1. Arithmetic Operators

# Arithmetic Operators
a = 15
b = 4

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Floor Division:", a // b)
print("Modulus:", a % b)
print("Exponentiation:", a ** b)

##🔍 2. Relational Operators

# Relational Operators
x = 10
y = 20

print("Equal to:", x == y)
print("Not equal to:", x != y)
print("Greater than:", x > y)
print("Less than:", x < y)
print("Greater than or equal to:", x >= y)
print("Less than or equal to:", x <= y)

##🧠 3. Logical Operators

# Logical Operators
p = True
q = False

print("Logical AND:", p and q)
print("Logical OR:", p or q)
print("Logical NOT p:", not p)
print("Logical NOT q:", not q)
# Out:
# Addition: 19
# Subtraction: 11
# Multiplication: 60
# Division: 3.75
# Floor Division: 3
# Modulus: 3
# Exponentiation: 50625
# Equal to: False
# Not equal to: True
# Greater than: False
# Less than: True
# Greater than or equal to: False
# Less than or equal to: True
# Logical AND: False
# Logical OR: True
# Logical NOT p: False
# Logical NOT q: True

# %%
## find customer_id,first_name,last_name,age,item,country
## find customers who have not placed any orders (use left join)
## find customers from USA who placed the orders
## get orders where amount >500 along with customer names
## find customers aged>25 who placed atleast one order
## find total amount spent by the customer
## find the customer who spent the highest total amount
## get avg order value per country
##count number of orders per country

# %%
⭐ 1. Find customer_id, first_name, last_name, age, item, country

Solution A — INNER JOIN

            SELECT
                c.customer_id,
                c.first_name,
                c.last_name,
                c.age,
                o.item,
                c.country
            FROM customers c
            JOIN orders o
                ON c.customer_id = o.customer_id;

Solution B — LEFT JOIN (keeps customers even without orders)
            SELECT
                c.customer_id,
                c.first_name,
                c.last_name,
                c.age,
                o.item,
                c.country
            FROM customers c
            LEFT JOIN orders o
                ON c.customer_id = o.customer_id;

Solution C — Using a subquery
          SELECT
              customer_id, first_name, last_name, age, country,
              (SELECT item FROM orders o WHERE o.customer_id = c.customer_id) AS item
          FROM customers c;
===================================================
⭐ 2. Find customers who have not placed any orders

Solution A — LEFT JOIN + NULL filter
            SELECT c.*
            FROM customers c
            LEFT JOIN orders o
                ON c.customer_id = o.customer_id
            WHERE o.customer_id IS NULL;

Solution B — NOT IN
          SELECT *
          FROM customers
          WHERE customer_id NOT IN (SELECT customer_id FROM orders);

Solution C — NOT EXISTS
            SELECT *
            FROM customers c
            WHERE NOT EXISTS (
                SELECT 1
                FROM orders o
                WHERE o.customer_id = c.customer_id
            );
==================================================
⭐ 3. Find customers from USA who placed orders

Solution A — INNER JOIN
            SELECT DISTINCT c.*
            FROM customers c
            JOIN orders o
                ON c.customer_id = o.customer_id
            WHERE c.country = 'USA';

Solution B — EXISTS
          SELECT *
          FROM customers c
          WHERE c.country = 'USA'
            AND EXISTS (
                  SELECT 1
                  FROM orders o
                  WHERE o.customer_id = c.customer_id
            );

Solution C — IN
          SELECT *
          FROM customers
          WHERE country = 'USA'
            AND customer_id IN (SELECT customer_id FROM orders);
=============================================
⭐ 4. Get orders where amount > 500 along with customer names

Solution A — JOIN
          SELECT
              o.order_id,
              o.amount,
              c.first_name,
              c.last_name
          FROM orders o
          JOIN customers c
              ON o.customer_id = c.customer_id
          WHERE o.amount > 500;

Solution B — Subquery
          SELECT *
          FROM orders
          WHERE amount > 500
            AND customer_id IN (SELECT customer_id FROM customers);

Solution C — EXISTS
          SELECT o.*, c.first_name, c.last_name
          FROM orders o
          JOIN customers c
              ON o.customer_id = c.customer_id
          WHERE o.amount > 500;
===============================================
⭐ 5. Find customers aged >25 who placed at least one order

Solution A — JOIN
          SELECT DISTINCT c.*
          FROM customers c
          JOIN orders o
              ON c.customer_id = o.customer_id
          WHERE c.age > 25;

Solution B — EXISTS
        SELECT *
        FROM customers c
        WHERE c.age > 25
          AND EXISTS (
                SELECT 1
                FROM orders o
                WHERE o.customer_id = c.customer_id
          );

Solution C — IN
        SELECT *
        FROM customers
        WHERE age > 25
          AND customer_id IN (SELECT customer_id FROM orders);
=========================================================
⭐ 6. Find total amount spent by each customer

Solution A — GROUP BY

        SELECT
            customer_id,
            SUM(amount) AS total_spent
        FROM orders
        GROUP BY customer_id;

Solution B — JOIN + GROUP BY
        SELECT
            c.customer_id,
            c.first_name,
            c.last_name,
            SUM(o.amount) AS total_spent
        FROM customers c
        JOIN orders o
            ON c.customer_id = o.customer_id
        GROUP BY c.customer_id, c.first_name, c.last_name;

Solution C — Window function
          SELECT DISTINCT
              customer_id,
              SUM(amount) OVER (PARTITION BY customer_id) AS total_spent
          FROM orders;
=====================================================
⭐ 7. Find the customer who spent the highest total amount

Solution A — ORDER BY + LIMIT

          SELECT
              customer_id,
              SUM(amount) AS total_spent
          FROM orders
          GROUP BY customer_id
          ORDER BY total_spent DESC
          LIMIT 1;

Solution B — Window function
            SELECT customer_id, total_spent
            FROM (
                SELECT
                    customer_id,
                    SUM(amount) AS total_spent,
                    RANK() OVER (ORDER BY SUM(amount) DESC) AS rnk
                FROM orders
                GROUP BY customer_id
            ) t
            WHERE rnk = 1;

Solution C — MAX + HAVING
              SELECT customer_id, SUM(amount) AS total_spent
              FROM orders
              GROUP BY customer_id
              HAVING SUM(amount) = (
                  SELECT MAX(total_spent)
                  FROM (
                      SELECT SUM(amount) AS total_spent
                      FROM orders
                      GROUP BY customer_id
                  ) x
              );
=========================================
⭐ 8. Get avg order value per country

Solution A — GROUP BY

          SELECT
              country,
              AVG(amount) AS avg_order_value
          FROM orders
          GROUP BY country;

Solution B — JOIN customers
          SELECT
              c.country,
              AVG(o.amount) AS avg_order_value
          FROM customers c
          JOIN orders o
              ON c.customer_id = o.customer_id
          GROUP BY c.country;

Solution C — Window function
          SELECT DISTINCT
              country,
              AVG(amount) OVER (PARTITION BY country) AS avg_order_value
          FROM orders;
===================================================
⭐ 9. Count number of orders per country

Solution A — GROUP BY

          SELECT
              country,
              COUNT(*) AS order_count
          FROM orders
          GROUP BY country;

Solution B — JOIN customers
          SELECT
              c.country,
              COUNT(o.order_id) AS order_count
          FROM customers c
          JOIN orders o
              ON c.customer_id = o.customer_id
          GROUP BY c.country;

Solution C — Window function
      SELECT DISTINCT
          country,
          COUNT(order_id) OVER (PARTITION BY country) AS order_count
      FROM orders;

# %%
##subquery - find customers older than average age
select * from customers where age > (select avg(age) from customers)

##  select customers who have placed the orders
select * from customers where customer_id in (select customer_id from orders)

## find customers who have not placed any orders
select * from customers where customer_id not in (select customer_id from orders)

# %%
## day sql-4

## get all the customers with their order items and shipping status. output: name, item, amount and status
##list all customers who have placed orders and have shipping status 'Delivered'
## find all customers who have orders but no shipping record

⭐ 1. Get all customers with their order items and shipping status
Output: name, item, amount, status**

Solution A — Straight JOIN
sql
            SELECT
                CONCAT(c.first_name, ' ', c.last_name) AS name,
                o.item,
                o.amount,
                s.status
            FROM customers c
            JOIN orders o
                ON c.customer_id = o.customer_id
            LEFT JOIN shippings s
                ON c.customer_id = s.customer_id;

Solution B — Using aliases + cleaner formatting
sql
          SELECT
              c.first_name || ' ' || c.last_name AS name,
              o.item,
              o.amount,
              s.status
          FROM customers c
          JOIN orders o ON c.customer_id = o.customer_id
          LEFT JOIN shippings s ON c.customer_id = s.customer_id;

Solution C — Only customers who have shipping records
sql
          SELECT
              CONCAT(c.first_name, ' ', c.last_name) AS name,
              o.item,
              o.amount,
              s.status
          FROM customers c
          JOIN orders o ON c.customer_id = o.customer_id
          JOIN shippings s ON c.customer_id = s.customer_id;

⭐ 2. List all customers who placed orders AND have shipping status = 'Delivered'
Your sample data has no Delivered rows, but the query is:

Solution A — JOIN + WHERE
sql
          SELECT DISTINCT
              c.customer_id,
              c.first_name,
              c.last_name
          FROM customers c
          JOIN orders o
              ON c.customer_id = o.customer_id
          JOIN shippings s
              ON c.customer_id = s.customer_id
          WHERE s.status = 'Delivered';

Solution B — EXISTS
sql
        SELECT
            c.customer_id,
            c.first_name,
            c.last_name
        FROM customers c
        WHERE EXISTS (
            SELECT 1
            FROM orders o
            JOIN shippings s
                ON o.customer_id = s.customer_id
            WHERE o.customer_id = c.customer_id
              AND s.status = 'Delivered'
        );

⭐ 3. Find all customers who have orders but NO shipping record
Solution A — LEFT JOIN + NULL
sql
          SELECT DISTINCT
              c.customer_id,
              c.first_name,
              c.last_name
          FROM customers c
          JOIN orders o
              ON c.customer_id = o.customer_id
          LEFT JOIN shippings s
              ON c.customer_id = s.customer_id
          WHERE s.customer_id IS NULL;

Solution B — NOT EXISTS
sql
          SELECT
              c.customer_id,
              c.first_name,
              c.last_name
          FROM customers c
          JOIN orders o
              ON c.customer_id = o.customer_id
          WHERE NOT EXISTS (
              SELECT 1
              FROM shippings s
              WHERE s.customer_id = c.customer_id
          );

Solution C — IN / NOT IN
sql
        SELECT
            c.customer_id,
            c.first_name,
            c.last_name
        FROM customers c
        WHERE c.customer_id IN (SELECT customer_id FROM orders)
          AND c.customer_id NOT IN (SELECT customer_id FROM shippings);

# %%
## left join use
## 4. find customers who have not placed any orders but have a shipping record
## 5. find customers from USA who placed the orders are still pending
## 6. list all customers along with total number of orders and their latest shipping status

# %%
##⭐ 4. Find customers who have not placed any orders but have a shipping record

Assume tables:

        customers(customer_id, first_name, …)

        orders(order_id, customer_id, …)

        shipments(shipment_id, order_id, status, …)

✅ Solution 1 — LEFT JOIN (classic interview style)
sql

      SELECT DISTINCT c.customer_id, c.first_name, c.last_name
      FROM customers c
      LEFT JOIN orders o ON c.customer_id = o.customer_id
      JOIN shipments s ON s.order_id = o.order_id
      WHERE o.order_id IS NULL;

Why it works
      LEFT JOIN ensures all customers appear

      o.order_id IS NULL → no orders

      But they still appear in shipments → means shipments exist for some order_id linked to them

✅ Solution 2 — NOT EXISTS (cleaner logic)
sql
      SELECT DISTINCT c.customer_id, c.first_name, c.last_name
      FROM customers c
      JOIN shipments s ON c.customer_id = s.customer_id
      WHERE NOT EXISTS (
          SELECT 1 FROM orders o
          WHERE o.customer_id = c.customer_id
      );

✅ Solution 3 — Anti-join using NOT IN
sql
        SELECT DISTINCT c.customer_id, c.first_name, c.last_name
        FROM customers c
        JOIN shipments s ON c.customer_id = s.customer_id
        WHERE c.customer_id NOT IN (
            SELECT customer_id FROM orders
        );

⭐ 5. Find customers from USA who placed orders that are still pending
Assume shipment status = 'Pending'.

✅ Solution 1 — JOIN all three tables
sql
        SELECT DISTINCT c.customer_id, c.first_name, c.last_name
        FROM customers c
        JOIN orders o ON c.customer_id = o.customer_id
        JOIN shipments s ON o.order_id = s.order_id
        WHERE c.country = 'USA'
          AND s.status = 'Pending';

✅ Solution 2 — Using EXISTS
sql
        SELECT c.customer_id, c.first_name, c.last_name
        FROM customers c
        WHERE c.country = 'USA'
          AND EXISTS (
                SELECT 1
                FROM orders o
                JOIN shipments s ON o.order_id = s.order_id
                WHERE o.customer_id = c.customer_id
                  AND s.status = 'Pending'
          );

✅ Solution 3 — Using subquery for pending orders
sql
        SELECT c.customer_id, c.first_name, c.last_name
        FROM customers c
        WHERE c.country = 'USA'
          AND c.customer_id IN (
                SELECT o.customer_id
                FROM orders o
                JOIN shipments s ON o.order_id = s.order_id
                WHERE s.status = 'Pending'
          );

⭐ 6. List all customers with total number of orders and their latest shipping status
Assume “latest” = max(shipment_date).

✅ Solution 1 — GROUP BY + window function
sql
        SELECT
            c.customer_id,
            c.first_name,
            c.last_name,
            COUNT(o.order_id) AS total_orders,
            s.status AS latest_status
        FROM customers c
        LEFT JOIN orders o ON c.customer_id = o.customer_id
        LEFT JOIN (
            SELECT
                order_id,
                status,
                ROW_NUMBER() OVER (PARTITION BY order_id ORDER BY shipment_date DESC) AS rn
            FROM shipments
        ) s ON o.order_id = s.order_id AND s.rn = 1
        GROUP BY c.customer_id, c.first_name, c.last_name, s.status;

✅ Solution 2 — Correlated subquery for latest shipment
sql
          SELECT
              c.customer_id,
              c.first_name,
              c.last_name,
              (SELECT COUNT(*) FROM orders o WHERE o.customer_id = c.customer_id) AS total_orders,
              (
                  SELECT s.status
                  FROM shipments s
                  JOIN orders o ON o.order_id = s.order_id
                  WHERE o.customer_id = c.customer_id
                  ORDER BY s.shipment_date DESC
                  LIMIT 1
              ) AS latest_status
          FROM customers c;

✅ Solution 3 — Two subqueries (clean teaching version)
sql
          SELECT
              c.customer_id,
              c.first_name,
              c.last_name,
              o.total_orders,
              s.latest_status
          FROM customers c
          LEFT JOIN (
              SELECT customer_id, COUNT(*) AS total_orders
              FROM orders
              GROUP BY customer_id
          ) o ON c.customer_id = o.customer_id
          LEFT JOIN (
              SELECT o.customer_id,
                    s.status AS latest_status
              FROM shipments s
              JOIN orders o ON s.order_id = o.order_id
              WHERE (s.order_id, s.shipment_date) IN (
                  SELECT order_id, MAX(shipment_date)
                  FROM shipments
                  GROUP BY order_id
              )
          ) s ON c.customer_id = s.customer_id;

# %%
## advanced
7. find total amount spent by each customer whose spipments are delivered
8. find the customer who spent the highest total amount
9. count number of orders per country
10 Find total revenue from pending shipments
11.get count of customers per shipping station
12.find the country contributing the highest delivered revenue

# %%
##✅ 7. Total amount spent by each customer whose shipments are delivered
sql
        SELECT
            c.customer_id,
            c.customer_name,
            SUM(o.order_amount) AS total_spent
        FROM customers c
        JOIN orders o
            ON c.customer_id = o.customer_id
        JOIN shipments s
            ON o.order_id = s.order_id
        WHERE s.shipment_status = 'Delivered'
        GROUP BY c.customer_id, c.customer_name;

✅ 8. Customer who spent the highest total amount
sql
        SELECT customer_id, customer_name, total_spent
        FROM (
            SELECT
                c.customer_id,
                c.customer_name,
                SUM(o.order_amount) AS total_spent,
                RANK() OVER (ORDER BY SUM(o.order_amount) DESC) AS rnk
            FROM customers c
            JOIN orders o
                ON c.customer_id = o.customer_id
            GROUP BY c.customer_id, c.customer_name
        ) t
        WHERE rnk = 1;

✅ 9. Count number of orders per country
sql
        SELECT
            c.country,
            COUNT(o.order_id) AS order_count
        FROM customers c
        JOIN orders o
            ON c.customer_id = o.customer_id
        GROUP BY c.country;

✅ 10. Total revenue from pending shipments
sql
        SELECT
            SUM(o.order_amount) AS pending_revenue
        FROM orders o
        JOIN shipments s
            ON o.order_id = s.order_id
        WHERE s.shipment_status = 'Pending';

✅ 11. Count of customers per shipping station
This assumes a customer is counted once per station based on their orders shipped from that station.

sql
        SELECT
            s.shipping_station,
            COUNT(DISTINCT o.customer_id) AS customer_count
        FROM shipments s
        JOIN orders o
            ON s.order_id = o.order_id
        GROUP BY s.shipping_station;

✅ 12. Country contributing the highest delivered revenue
sql
        SELECT country, delivered_revenue
        FROM (
            SELECT
                c.country,
                SUM(o.order_amount) AS delivered_revenue,
                RANK() OVER (ORDER BY SUM(o.order_amount) DESC) AS rnk
            FROM customers c
            JOIN orders o
                ON c.customer_id = o.customer_id
            JOIN shipments s
                ON o.order_id = s.order_id
            WHERE s.shipment_status = 'Delivered'
            GROUP BY c.country
        ) t
        WHERE rnk = 1;

# %%
🚀 Overall Performance Principles

Fastest → Slowest (general rule)
        JOIN + WHERE

        EXISTS / NOT EXISTS

        IN / NOT IN

        LEFT JOIN + NULL filter

        EXCEPT / INTERSECT (depends on engine, often slower)

Why?
        JOINs use indexed paths efficiently.
        EXISTS stops scanning early.
        IN/NOT IN may materialize sets.
        LEFT JOIN + NULL requires scanning both sides.
        EXCEPT sorts/deduplicates → expensive.

⭐ Query 1: Get customers + items + amount + shipping status
✔ Best Performance
JOIN + LEFT JOIN (Solution A/B)
sql
        SELECT ...
        FROM customers c
        JOIN orders o ON c.customer_id = o.customer_id
        LEFT JOIN shippings s ON c.customer_id = s.customer_id;

Why it’s fastest
        Uses direct indexed joins on primary/foreign keys.
        LEFT JOIN is cheap because it’s on customer_id (likely indexed).
        No subqueries, no deduplication.

❌ Less efficient
      Using INNER JOIN on shippings (Solution C) is not slower,
      but it drops customers without shipping, which may not be desired.

⭐ Query 2: Customers with orders AND shipping status = 'Delivered'
✔ Best Performance
JOIN + WHERE (Solution A)
sql
        SELECT DISTINCT ...
        FROM customers c
        JOIN orders o ON c.customer_id = o.customer_id
        JOIN shippings s ON c.customer_id = s.customer_id
        WHERE s.status = 'Delivered';
Why?
      Straight join + filter → uses indexes efficiently.
      DISTINCT is cheap because customer_id is small.

✔ Also excellent
EXISTS (Solution B)
sql
        WHERE EXISTS (
            SELECT 1 ...
        )

Why?
      EXISTS stops scanning as soon as it finds a match.
      Very efficient when customers have many orders.

❌ Less efficient
    IN (Solution C)
    Materializes a list → slower than EXISTS.

⭐ Query 3: Customers with orders but NO shipping record
✔ Best Performance
    NOT EXISTS (Solution B)

sql
      WHERE NOT EXISTS (
          SELECT 1
          FROM shippings s
          WHERE s.customer_id = c.customer_id
      );
Why?
NOT EXISTS is the gold standard for anti‑joins.
Stops early.
Avoids NULL pitfalls.

✔ Also good
LEFT JOIN + NULL (Solution A)

sql
      LEFT JOIN shippings s ...
      WHERE s.customer_id IS NULL;
Why?
Very readable.
Optimizer often rewrites it into NOT EXISTS internally.

❌ Slowest
NOT IN (Solution C)

sql
    c.customer_id NOT IN (SELECT customer_id FROM shippings)

Why?
NOT IN + NULLs = tricky semantics.
Requires full scan of the subquery.
Often forces the engine to materialize the set.

🏆 Final Ranking Summary

Query	Fastest Approach	Why
1. Customers + items + shipping	JOIN + LEFT JOIN	Direct indexed joins, no subqueries
2. Delivered customers	JOIN + WHERE or EXISTS	Both use indexes efficiently; EXISTS short‑circuits
3. Orders but no shipping	NOT EXISTS	Best anti‑join pattern, avoids NULL issues

# %%
##windows functions-> row_number, dense_rank,rank
row_number()

select item,amount, row_number() over(order by amount desc) as rnk
from orders

# %%
--rank() -> it will skip the ranknumber
select first_name,age ,
rank() over (order by age desc) as rnk
from customers

# %%
--dense_rank() -> it wont skil
select first_name,age ,
dense_rank() over (order by age desc) as rnk
from customers

# %%
1. Find the total number of users.
2. Find total number of applications for each country.
3. Find total number of approved applications.
4. Find users who signed up but never created any application.
5. Find applications that do not have a successful payment.
6. Find total revenue from successful payments.
7. Find average payment amount per country (only successful payments).
8. Find daily number of applications.
9. Find conversion rate from application to successful payment.
10. Find the country with the highest revenue.

# %%
CREATE TABLE users (
    user_id INT PRIMARY KEY,
    signup_date DATE
);
INSERT INTO users VALUES
(1, '2024-01-01'),
(2, '2024-01-05'),
(3, '2024-01-10'),
(4, '2024-01-15'),
(5, '2024-02-01'),
(6, '2024-02-10'),
(7, '2024-02-15'),
(8, '2024-03-01');

CREATE TABLE applications (
    app_id INT PRIMARY KEY,
    user_id INT,
    country VARCHAR(50),
    status VARCHAR(50),
    created_at TIMESTAMP,
    FOREIGN KEY (user_id) REFERENCES users(user_id)
);
INSERT INTO applications VALUES
(101, 1, 'USA', 'approved', '2024-01-02 10:00:00'),
(102, 1, 'Canada', 'rejected', '2024-01-10 12:00:00'),
(103, 2, 'USA', 'payment_done', '2024-01-06 09:00:00'),
(104, 3, 'UK', 'docs_uploaded', '2024-01-12 14:00:00'),
(105, 4, 'USA', 'started', '2024-01-16 16:00:00'),
(106, 5, 'Germany', 'approved', '2024-02-02 11:00:00'),
(107, 5, 'USA', 'payment_done', '2024-02-05 13:00:00'),
(108, 6, 'Canada', 'approved', '2024-02-11 15:00:00'),
(109, 7, 'UK', 'rejected', '2024-02-16 17:00:00'),
(110, 7, 'USA', 'docs_uploaded', '2024-02-18 18:00:00');
CREATE TABLE payments (/
    payment_id INT PRIMARY KEY,
    app_id INT,
    amount DECIMAL(10,2),
    status VARCHAR(50),
    payment_date DATE,
    FOREIGN KEY (app_id) REFERENCES applications(app_id)
);

INSERT INTO payments VALUES
(201, 101, 5000, 'success', '2024-01-03'),
(202, 102, 4000, 'failed', '2024-01-11'),
(203, 103, 5500, 'success', '2024-01-07'),
(204, 106, 6000, 'success', '2024-02-03'),
(205, 107, 5200, 'failed', '2024-02-06'),
(206, 108, 4500, 'success', '2024-02-12'

# %%
### Numpy Exercices
======================================
1. Create a NumPy array of numbers from 1 to 20.
○ Print the first 5 elements.
○ Print the last 5 elements.
○ Print every 2nd element.
2. Create a 2D NumPy array of shape (4, 5) with numbers from 1 to 20.
○ Print the 2nd row.
○ Print the 3rd column.
○ Slice a sub-array containing rows 2–3 and columns 2–4.
3. Create a 5x5 NumPy array filled with random integers (1–100).
○ Find the maximum and minimum value.
○ Find the sum of all elements.
○ Find the mean of each row.
4. Reshape an array of numbers from 1 to 12 into a 3x4 array.
○ Print the transpose of this array.
○ Flatten the array back to 1D.
5. Create two NumPy arrays of length 5.
○ Add, subtract, multiply, and divide them element-wise.
○ Perform a dot product between them.
-------------------------
Pandas Section
Dataset to Use (Example):
          import pandas as pd
          data = {
          "Name": ["Amit", "Riya", "Sam", "Neha", "Raj"],
          "Age": [23, 21, 25, 22, 24],
          "Department": ["HR", "IT", "Finance", "IT", "HR"],
          "Salary": [25000, 30000, 28000, 35000, 27000]
          }
          df = pd.DataFrame(data)

1. Display:
○ First 3 rows of the dataframe.
○ Last 2 rows of the dataframe.
○ Summary statistics of numeric columns.
2. Select:
○ The Name column.
○ The Age and Salary columns together.
○ The 2nd and 4th row using .iloc.
○ All rows where Department = "IT".
3. Filtering:
○ Find employees with Salary > 28000.
○ Find employees whose Age is between 22 and 24.
○ Find employees not in the "HR" department.
4. Sorting & Aggregation:
○ Sort employees by Salary in descending order.

○ Group employees by Department and find the average Salary.
○ Count how many employees are in each Department.
5. Data Manipulation:
○ Add a new column Bonus = 10% of Salary.
○ Update Neha’s Age to 23.
○ Remove Raj’s row from the dataframe.
==========================
1. Create a NumPy array of numbers from 1 to 20.
○ Print the first 5 elements.
○ Print the last 5 elements.
○ Print every 2nd element.
=============================
🌟 NumPy Section

            import numpy as np
            1. Array from 1 to 20
            python
            arr = np.arange(1, 21)

            print(arr[:5])      # first 5
            print(arr[-5:])     # last 5
            print(arr[::2])     # every 2nd element
============================
2. Create a 2D NumPy array of shape (4, 5) with numbers from 1 to 20.
○ Print the 2nd row.
○ Print the 3rd column.
○ Slice a sub-array containing rows 2–3 and columns 2–4.
==============================
2. 2D Array (4×5)
python
            arr2d = np.arange(1, 21).reshape(4, 5)

            print(arr2d[1])          # 2nd row
            print(arr2d[:, 2])       # 3rd column
            print(arr2d[1:3, 1:4])   # rows 2–3, cols 2–4
==============================
3. Create a 5x5 NumPy array filled with random integers (1–100).
○ Find the maximum and minimum value.
○ Find the sum of all elements.
○ Find the mean of each row.
=================================
3. Random 5×5 Array
python
            rand_arr = np.random.randint(1, 101, size=(5, 5))

            print(rand_arr.max())
            print(rand_arr.min())
            print(rand_arr.sum())
            print(rand_arr.mean(axis=1))   # mean of each row
================================
4. Reshape an array of numbers from 1 to 12 into a 3x4 array.
○ Print the transpose of this array.
○ Flatten the array back to 1D.
===========================
4. Reshape 1–12 into 3×4
python
          arr = np.arange(1, 13).reshape(3, 4)

          print(arr.T)        # transpose
          print(arr.flatten()) # back to 1D
=====================
5. Create two NumPy arrays of length 5.
○ Add, subtract, multiply, and divide them element-wise.
○ Perform a dot product between them.
======================
5. Two Arrays of Length 5
python
          a = np.array([1, 2, 3, 4, 5])
          b = np.array([5, 4, 3, 2, 1])

          print(a + b)
          print(a - b)
          print(a * b)
          print(a / b)
          print(np.dot(a, b))   # dot product
======================================

🐼 Pandas Section

Dataset to Use (Example):
          import pandas as pd
          data = {
          "Name": ["Amit", "Riya", "Sam", "Neha", "Raj"],
          "Age": [23, 21, 25, 22, 24],
          "Department": ["HR", "IT", "Finance", "IT", "HR"],
          "Salary": [25000, 30000, 28000, 35000, 27000]
          }
          df = pd.DataFrame(data)
=============================
1. Display:
○ First 3 rows of the dataframe.
○ Last 2 rows of the dataframe.
○ Summary statistics of numeric columns.
========================
1. Display
python
          print(df.head(3))     # first 3 rows
          print(df.tail(2))     # last 2 rows
          print(df.describe())  # summary stats
=============
2. Select:
○ The Name column.
○ The Age and Salary columns together.
○ The 2nd and 4th row using .iloc.
○ All rows where Department = "IT".
==========================
2.Select
          print(df["Name"])                 # Name column
          print(df[["Age", "Salary"]])      # Age + Salary
          print(df.iloc[[1, 3]])            # 2nd & 4th row
          print(df[df["Department"] == "IT"])

===============
3. Filtering:
○ Find employees with Salary > 28000.
○ Find employees whose Age is between 22 and 24.
○ Find employees not in the "HR" department.
====================

python
            print(df[df["Salary"] > 28000])

            print(df[df["Age"].between(22, 24)])

            print(df[df["Department"] != "HR"])
=====================
4. Sorting & Aggregation:
○ Sort employees by Salary in descending order.

○ Group employees by Department and find the average Salary.
○ Count how many employees are in each Department.
=======================

            print(df.sort_values("Salary", ascending=False))

            print(df.groupby("Department")["Salary"].mean())

            print(df["Department"].value_counts())
==================
5. Data Manipulation:
○ Add a new column Bonus = 10% of Salary.
○ Update Neha’s Age to 23.
○ Remove Raj’s row from the dataframe.

======================
5. Data Manipulation
python
            df["Bonus"] = df["Salary"] * 0.10

            df.loc[df["Name"] == "Neha", "Age"] = 23

            df = df[df["Name"] != "Raj"]

            print(df)

# %%
####### Dictionary exercises
=========================
Basic Level
1. Create a dictionary of 5 students with their marks. Print each student’s name and
marks.
2. Add a new key–value pair to an existing dictionary and remove one key.
3. Write a program to check if a given key exists in the dictionary.
4. Given a dictionary of items and prices, print only the items that cost more than 100.

Intermediate Level
5. Create a dictionary of countries and their capitals. Write a program to:
○ Print all countries.
○ Print all capitals.
○ Ask the user to enter a country and display its capital.
6. Write a program to count the frequency of each character in a string using a
dictionary.
7. Given a dictionary of employees with their salary, find the employee with the highest
salary.
8. Write a program to merge two dictionaries.
Here you go, Anu — a clean, clear, beginner‑friendly + slightly challenging set of solutions for all 8 problems.
I’ll give you short explanations + runnable Python code so you can practice immediately.
===============================
🌱 BASIC LEVEL
1️⃣ Create a dictionary of 5 students with marks & print each
python
          students = {
              "Alice": 85,
              "Bob": 92,
              "Charlie": 78,
              "David": 88,
              "Eva": 95
          }

          for name, marks in students.items():
              print(name, ":", marks)

2️⃣ Add a new key–value pair & remove one
python
            person = {"name": "Anu", "age": 25}

            # Add
            person["city"] = "Seattle"

            # Remove
            del person["age"]

            print(person)

3️⃣ Check if a given key exists
python
          data = {"a": 1, "b": 2, "c": 3}

          key = input("Enter key to check: ")

          if key in data:
              print("Key exists")
          else:
              print("Key does not exist")

4️⃣ Print items costing more than 100
python
            items = {
                "Bag": 120,
                "Pen": 20,
                "Shoes": 250,
                "Book": 90,
                "Watch": 300
            }

            for item, price in items.items():
                if price > 100:
                    print(item, ":", price)
====================================================
🌿 INTERMEDIATE LEVEL
5️⃣ Countries & capitals dictionary
a) Print all countries
b) Print all capitals
c) Ask user for a country → show capital

python
        countries = {
            "India": "New Delhi",
            "USA": "Washington D.C.",
            "France": "Paris",
            "Japan": "Tokyo",
            "Germany": "Berlin"
        }

# Print all countries
        print("Countries:")
        for country in countries.keys():
            print(country)

# Print all capitals
      print("\nCapitals:")
      for capital in countries.values():
          print(capital)

# Ask user
        user_country = input("\nEnter a country: ")

        if user_country in countries:
            print("Capital:", countries[user_country])
        else:
            print("Country not found")

6️⃣ Count frequency of each character in a string
python
        text = input("Enter a string: ")

        freq = {}

        for ch in text:
            if ch in freq:
                freq[ch] += 1
            else:
                freq[ch] = 1

        print(freq)

7️⃣ Find employee with highest salary
python
        employees = {
            "Anu": 75000,
            "Ravi": 82000,
            "Meera": 68000,
            "John": 90000,
            "Sara": 88000
        }

        highest = max(employees, key=employees.get)

        print("Employee with highest salary:", highest, "→", employees[highest])

8️⃣ Merge two dictionaries

Method 1: Using update()
      python
      d1 = {"a": 1, "b": 2}
      d2 = {"c": 3, "d": 4}

      d1.update(d2)
      print(d1)

Method 2: Using unpacking (Python 3.5+)
        python
        merged = {**d1, **d2}
        print(merged)
