# %% [markdown]
# <a href="https://colab.research.google.com/github/anuvishalp/Python_fundamentals-B28/blob/master/Police_data-Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
import pandas as pd

# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-2ac44d26-cbd3-493c-9fc6-73ba01c973a1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2ac44d26-cbd3-493c-9fc6-73ba01c973a1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
police_data= pd.read_csv("PoliceData.csv")

# %%
police_data
# Out:
#        stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0       1/2/2005      1:55           NaN             M          1985.0
# 1      1/18/2005      8:15           NaN             M          1965.0
# 2      1/23/2005     23:15           NaN             M          1972.0
# 3      2/20/2005     17:15           NaN             M          1986.0
# 4      3/14/2005     10:00           NaN             F          1984.0
# ...          ...       ...           ...           ...             ...
# 65530  12/6/2012     17:54           NaN             F          1987.0
# 65531  12/6/2012     22:22           NaN             M          1954.0
# 65532  12/6/2012     23:20           NaN             M          1985.0
# 65533  12/7/2012      0:23           NaN           NaN             NaN
# 65534  12/7/2012      0:30           NaN             F          1985.0
#
#        driver_age driver_race                   violation_raw  violation  \
# ...

# %%
police_data.shape
# Out:
# (65535, 15)

# %%
police_data.isnull()
# Out:
#        stop_date  stop_time  country_name  driver_gender  driver_age_raw  \
# 0          False      False          True          False           False
# 1          False      False          True          False           False
# 2          False      False          True          False           False
# 3          False      False          True          False           False
# 4          False      False          True          False           False
# ...          ...        ...           ...            ...             ...
# 65530      False      False          True          False           False
# 65531      False      False          True          False           False
# 65532      False      False          True          False           False
# 65533      False      False          True           True            True
# 65534      False      False          True          False           False
#
#        driver_age  driver_race  violation_raw  violation  search_conducted  \
# ...

# %%
police_data.drop('country_name', axis=1)
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0       1/2/2005      1:55             M          1985.0        20.0
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 3      2/20/2005     17:15             M          1986.0        19.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# ...          ...       ...           ...             ...         ...
# 65530  12/6/2012     17:54             F          1987.0        25.0
# 65531  12/6/2012     22:22             M          1954.0        58.0
# 65532  12/6/2012     23:20             M          1985.0        27.0
# 65533  12/7/2012      0:23           NaN             NaN         NaN
# 65534  12/7/2012      0:30             F          1985.0        27.0
#
#       driver_race                   violation_raw  violation  \
# 0           White                        Speeding   Speeding
# ...

# %%
police_data
# Out:
#        stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0       1/2/2005      1:55           NaN             M          1985.0
# 1      1/18/2005      8:15           NaN             M          1965.0
# 2      1/23/2005     23:15           NaN             M          1972.0
# 3      2/20/2005     17:15           NaN             M          1986.0
# 4      3/14/2005     10:00           NaN             F          1984.0
# ...          ...       ...           ...           ...             ...
# 65530  12/6/2012     17:54           NaN             F          1987.0
# 65531  12/6/2012     22:22           NaN             M          1954.0
# 65532  12/6/2012     23:20           NaN             M          1985.0
# 65533  12/7/2012      0:23           NaN           NaN             NaN
# 65534  12/7/2012      0:30           NaN             F          1985.0
#
#        driver_age driver_race                   violation_raw  violation  \
# ...

# %%
#remove the column that contains missing values
police_data.drop('country_name', axis=1, inplace=True)

# %%
police_data
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0       1/2/2005      1:55             M          1985.0        20.0
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 3      2/20/2005     17:15             M          1986.0        19.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# ...          ...       ...           ...             ...         ...
# 65530  12/6/2012     17:54             F          1987.0        25.0
# 65531  12/6/2012     22:22             M          1954.0        58.0
# 65532  12/6/2012     23:20             M          1985.0        27.0
# 65533  12/7/2012      0:23           NaN             NaN         NaN
# 65534  12/7/2012      0:30             F          1985.0        27.0
#
#       driver_race                   violation_raw  violation  \
# 0           White                        Speeding   Speeding
# ...

# %%
police_data.head()
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0   1/2/2005      1:55             M          1985.0        20.0       White
# 1  1/18/2005      8:15             M          1965.0        40.0       White
# 2  1/23/2005     23:15             M          1972.0        33.0       White
# 3  2/20/2005     17:15             M          1986.0        19.0       White
# 4  3/14/2005     10:00             F          1984.0        21.0       White
#
#       violation_raw violation  search_conducted search_type   stop_outcome  \
# 0          Speeding  Speeding             False         NaN       Citation
# 1          Speeding  Speeding             False         NaN       Citation
# 2          Speeding  Speeding             False         NaN       Citation
# 3  Call for Service  Speeding             False         NaN  Arrest Driver
# 4          Speeding  Speeding             False         NaN       Citation
#
#   is_arrested stop_duration  drugs_related_stop
# ...

# %%
police_data.violation='Speeding'

# %%
#for speeding, were men or women stopped more often?
police_data[police_data.violation=='Speeding'].driver_gender.value_counts()
# Out:
# driver_gender
# M    45164
# F    16310
# Name: count, dtype: int64

# %%
#does gender affect who gets searched during a stop?
police_data.head(2)

# %%
police_data.groupby('driver_gender').search_conducted.sum()
# Out:
# driver_gender
# F     366
# M    2113
# Name: search_conducted, dtype: int64

# %%
police_data.groupby('driver_gender').search_conducted.value_counts()
# Out:
# driver_gender  search_conducted
# F              False               15944
#                True                  366
# M              False               43051
#                True                 2113
# Name: count, dtype: int64

# %%
police_data.search_conducted.value_counts()
# Out:
# search_conducted
# False    63056
# True      2479
# Name: count, dtype: int64

# %%
police_data.search_conducted.sum()
# Out:
# np.int64(2479)

# %%
police_data.search_conducted.value_counts()
# Out:
# search_conducted
# False    63056
# True      2479
# Name: count, dtype: int64

# %%
#what is the mean stop_duration?
police_data.head(2)
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0   1/2/2005      1:55             M          1985.0        20.0       White
# 1  1/18/2005      8:15             M          1965.0        40.0       White
#
#   violation_raw violation  search_conducted search_type stop_outcome  \
# 0      Speeding  Speeding             False         NaN     Citation
# 1      Speeding  Speeding             False         NaN     Citation
#
#   is_arrested stop_duration  drugs_related_stop
# 0       False      0-15 Min               False
# 1       False      0-15 Min               False

# %%
police_data.stop_duration.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
police_data['stop_duration']=police_data['stop_duration'].map({'0-15 Min' : 7.5, '16-30 Min' : 30, '30+ Min' : 45})

# %%
police_data['stop_duration']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 65530   NaN
# 65531   NaN
# 65532   NaN
# 65533   NaN
# 65534   NaN
# Name: stop_duration, Length: 65535, dtype: float64

# %%
police_data['stop_duration'].unique()
# Out:
# array([nan])

# %%
police_data['stop_duration'].value_counts(dropna=False)
# Out:
# stop_duration
# NaN    65535
# Name: count, dtype: int64

# %%
police_data['stop_duraton'].mean()

# %%
#compare the age distributions for each violation
police_data.groupby('violation').driver_age.describe()
# Out:
#              count       mean       std   min   25%   50%   75%   max
# violation
# Speeding   61228.0  34.148984  12.76071  15.0  23.0  31.0  43.0  88.0
