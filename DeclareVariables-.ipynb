# %% [markdown]
# <a href="https://colab.research.google.com/github/anuvishalp/Python_DataCleaning-Basics/blob/master/DeclareVariables-.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#control ?
# a
# b
# c

# %%
x='Hello World'
print(x)
# Out:
# Hello World

# %%
#program to add 2 numbers
a=7
b=8
c=a+b
print(c)
# Out:
# 15

# %%
#program to check 2 numbers with casting feature
x=int(input('enter the first number'))
y=int(input('enter the second number'))
z=x+y
print(z)
# Out:
# enter the first number1
# enter the second number3
# 4

# %%
#program to add 3 numbers, by taking the input of 3 numbers.store in 4th variable.display the result
x1=int(input('enter first number'))
x2=int(input('enter second number'))
x3=int(input('enter third number'))

x4=x1+x2+x3
print(x4)
# Out:
# enter first number1
# enter second number2
# enter third number3
# 6

# %%
# program to test the eligiibility of driving
#age=18
#if age>18 print(eligible)
#else print('ineligible)'

x=int(input('enter your age:'))
if x>=18 :
  print("you are eligible to drive")
else:
  print('not eligible')
# Out:
# enter your age:2
# not eligible

# %%
#Program- to test the voting eligibility, asking to enter age. if age>25 eligible to vote. else he cant vote

x=int(input('enter your age to check the voting eligibility'))

if x>=25:
  print('you are eligible to vote')
else:
  print('you are not eligible to vote')
# Out:
# enter your age to check the voting eligibility2
# you are not eligible to vote

# %%
# program to check whether the entered number is even or odd number
x=int(input('enter one number to test the even or odd: '))
if x%2==0:
  print('even number')
else:
  print('odd number')
# Out:
# enter one number to test the even or odd53
# odd number

# %%
#program to check the result of 2 numbers as even or odd number

x1=int(input('enter first number'))
x2=int(input('enter second number'))

x3=x1+x2
print x3
if x3%2==0:
  print('even number')
else:
  print('odd number')
# Out:
# enter first number14
# enter second number39
# odd number

# %%
#program to check the entered letter is consonant or vowel
x=str(input('enter the letter- '))

if x in ['a','e','i','o','u'] :
  print('vowel')
else:
  print('consonant')
# Out:
# enter the letterr
# consonant
