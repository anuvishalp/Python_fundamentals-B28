# %% [markdown]
# <a href="https://colab.research.google.com/github/anuvishalp/Python_DataCleaning-Basics/blob/master/UdemyCourses_dataCleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
import pandas as pd

# %%
#from google.colab import drive
#drive.mount('/content/drive')

from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-f9d3cf39-ee2d-431d-8716-b0a9f70f9149" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f9d3cf39-ee2d-431d-8716-b0a9f70f9149">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
udemy_courses=pd.read_csv('UdemyCourses.csv')

# %%
#what are the different subjects/courses udemy offers?
#find out the maximum number of courses each category has?
#show all the courses which are free of cost
#show all the courses which are paid
#which are the top selling courses?
#which are the least selling courses?
#show all the courses of grafic design,wbere the prices are below 100.
#find out all the courses which are related to python
#courses published in 2017
#what are the maximum number of subscribers for each level of courses

# %%
udemy_courses.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# ...

# %%
udemy_courses.shape
# Out:
# (3682, 11)

# %%
udemy_courses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3682 entries, 0 to 3681
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3682 non-null   int64
#  1   course_title         3682 non-null   object
#  2   is_paid              3682 non-null   bool
#  3   price                3682 non-null   object
#  4   num_subscribers      3682 non-null   int64
#  5   num_reviews          3682 non-null   int64
#  6   num_lectures         3682 non-null   int64
#  7   level                3682 non-null   object
#  8   content_duration     3682 non-null   object
#  9   published_timestamp  3682 non-null   object
#  10  subject              3682 non-null   object
# dtypes: bool(1), int64(4), object(6)
# memory usage: 291.4+ KB

# %%
udemy_courses.describe()
# Out:
#           course_id  num_subscribers   num_reviews  num_lectures
# count  3.682000e+03      3682.000000   3682.000000   3682.000000
# mean   6.766121e+05      3194.230310    156.093156     40.065182
# std    3.436355e+05      9499.378361    934.957204     50.373299
# min    8.324000e+03         0.000000      0.000000      0.000000
# 25%    4.078430e+05       110.250000      4.000000     15.000000
# 50%    6.885580e+05       911.500000     18.000000     25.000000
# 75%    9.617515e+05      2540.250000     67.000000     45.000000
# max    1.282064e+06    268923.000000  27445.000000    779.000000

# %%
udemy_courses.isnull().sum()
# Out:
# course_id              0
# course_title           0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
udemy_courses.duplicated().sum()
# Out:
# np.int64(6)

# %%
udemy_courses.nunique()
# Out:
# course_id              3676
# course_title           3667
# is_paid                   2
# price                    38
# num_subscribers        2198
# num_reviews             511
# num_lectures            229
# level                     4
# content_duration        109
# published_timestamp    3676
# subject                   4
# dtype: int64

# %%
udemy_courses.columns
udemy_courses.subject.unique()
# Out:
# array(['Musical Instruments', 'Business Finance', 'Graphic Design',
#        'Web Development'], dtype=object)

# %%
udemy_courses.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
udemy_courses.subject.unique()
# Out:
# array(['Musical Instruments', 'Business Finance', 'Graphic Design',
#        'Web Development'], dtype=object)

# %%
udemy_courses.subject.value_counts()
# Out:
# subject
# Web Development        1200
# Business Finance       1199
# Musical Instruments     680
# Graphic Design          603
# Name: count, dtype: int64

# %%
udemy_courses.is_paid == False
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3677    False
# 3678    False
# 3679    False
# 3680     True
# 3681    False
# Name: is_paid, Length: 3682, dtype: bool

# %%
udemy_courses[udemy_courses.is_paid == False]
# Out:
#       course_id                                       course_title  is_paid  \
# 41       286070        5 lecciones que todo guitarrista debe tomar    False
# 49       696630  7 Ways A Beginner Guitarist Can Sound Better, ...    False
# 57       955914  A beginner`s guide to fingerpicking and strumm...    False
# 67       270976                             A how to guide in HTML    False
# 74      1214144  ¡Triunfar en La Bolsa de Valores No Requiere d...    False
# ...         ...                                                ...      ...
# 3620     552598  WordPress in under an hour - Create/manage you...    False
# 3638    1068590                     Wordpress Website Mastery 2017    False
# 3652     752706  Write quicker HTML5 and CSS 3; productivity ha...    False
# 3674    1257976  Your First 10 Guitar Lessons - Learn how to pl...    False
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
#
# ...

# %%
udemy_courses[udemy_courses.is_paid == False].shape
# Out:
# (310, 11)

# %%
udemy_courses[udemy_courses.is_paid == True].shape
# Out:
# (3372, 11)

# %%
#top selling courses
udemy_courses.head(1)
udemy_courses.sort_values('num_subscribers',ascending=False)
# Out:
#       course_id                                       course_title  is_paid  \
# 2230      41295               Learn HTML5 Programming From Scratch    False
# 776       59014                     Coding for Entrepreneurs Basic    False
# 3385     625204                         The Web Developer Bootcamp     True
# 640      173548  Build Your First Website in 1 Week with HTML5 ...    False
# 3316     764164              The Complete Web Developer Course 2.0     True
# ...         ...                                                ...      ...
# 1390    1136038          Free Ways to Create Passive Income Online     True
# 1909    1157298  Introduction to Forex Trading Business For Beg...     True
# 1910    1157298  Introduction to Forex Trading Business For Beg...     True
# 1325    1187084  Forex how traders beat the markest with little...     True
# 44      1231958        60 Minutes to Fundamental Accounting Skills     True
#
# ...

# %%
udemy_courses.sort_values('num_subscribers')
# Out:
#       course_id                                       course_title  is_paid  \
# 98      1219820  Accounting - The 6 most important rules you mu...     True
# 2350     371900  Learn to create Text fire effect in Adobe Phot...     True
# 3221    1057040                           Teeter-Totter Accounting     True
# 649     1233314                      Building a Balanced Scorecard     True
# 954     1169196  Credit concepts and checklist for bankers, cre...     True
# ...         ...                                                ...      ...
# 3316     764164              The Complete Web Developer Course 2.0     True
# 640      173548  Build Your First Website in 1 Week with HTML5 ...    False
# 3385     625204                         The Web Developer Bootcamp     True
# 776       59014                     Coding for Entrepreneurs Basic    False
# 2230      41295               Learn HTML5 Programming From Scratch    False
#
# ...

# %%
udemy_courses.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
udemy_courses.subject == 'Graphic Design'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3677    False
# 3678    False
# 3679    False
# 3680    False
# 3681     True
# Name: subject, Length: 3682, dtype: bool

# %%
udemy_courses[udemy_courses.subject == 'Graphic Design']
# Out:
#       course_id                                       course_title  is_paid  \
# 8        206592  :::Beginners Guide To Creating Amazing Images ...     True
# 20      1165268  15  Motion Graphic Elements in After Effect (S...     True
# 35      1164876  3DS MAX - Learn 3Ds MAX tutorial for Beginners...     True
# 39       599652                     48 Logo Designs and Techniques     True
# 47      1269190          7 Secrets To Designing In Black and White     True
# ...         ...                                                ...      ...
# 3588    1131780  Whiteboard Animation, Beginner To Expert - In ...     True
# 3594     908664  Word Swag : Create Stunning Images with the Wo...     True
# 3639    1122306         Wordpress: Comment utiliser le thème FABLE     True
# 3671     144222  YOU can Draw, Shade and Paint a Mixed Media Gi...     True
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %%
udemy_courses[(udemy_courses.subject =='Graphic Design') & (udemy_courses.price < '100')]
# Out:
# Empty DataFrame
# Columns: [course_id, course_title, is_paid, price, num_subscribers, num_reviews, num_lectures, level, content_duration, published_timestamp, subject]
# Index: []

# %%
udemy_courses[(udemy_courses.subject == 'Graphic Design') & (udemy_courses.price == '100')]
# Out:
#       course_id                                       course_title  is_paid  \
# 47      1269190          7 Secrets To Designing In Black and White     True
# 169      983444       Adobe Illustrator Vectors For Hand Letterers     True
# 184      638040  Adobe Photoshop Essentials: Master Adobe Photo...     True
# 520      978462              Blender Modelling Series - Volume Two     True
# 699      757900                          Canva : Book Cover Design     True
# 1029    1160004                 Design a logo for FREE in Inkscape     True
# 1071    1161864  Diseño impreso - Preimpresión para offset en I...     True
# 1444     490392                Getting Started with Illustrator CC     True
# 1568     727510             How To Become An Etsy Wholesale Seller     True
# 1616     996868          How to Design a Logo in Adobe Illustrator     True
# 1697     654038              How To Sell Your Art Online With ETSY     True
# ...

# %%
udemy_courses.course_title.str.contains('Python')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3677    False
# 3678    False
# 3679    False
# 3680    False
# 3681    False
# Name: course_title, Length: 3682, dtype: bool

# %%
udemy_courses.course_title.str.contains('Python').shape
# Out:
# (3682,)

# %%
udemy_courses[udemy_courses.course_title.str.contains('Python')]
# Out:
#       course_id                                       course_title  is_paid  \
# 216      599504  Advanced Scalable Python Web Development Using...     True
# 777       47963  Coding for Entrepreneurs: Learn Python, Django...     True
# 814      631128  Complete Python Web Course: Build 8 Python Web...     True
# 842      186096  Core: A Web App Reference Guide for Django, Py...     True
# 1400     394832  Fun and creative web engineering with Python a...    False
# 1932    1038538            Introduction to QGIS Python Programming     True
# 1969     902888          Investment Portfolio Analysis with Python     True
# 2294     391546        Learn Python and Django: Payment Processing     True
# 2295    1063722            Learn Python Django - A Hands-On Course     True
# 2341     546848  Learn to code in Python and learn Adobe Photos...     True
# 2906     368340    Professional Python Web Development Using Flask     True
# ...

# %%
len(udemy_courses[udemy_courses.course_title.str.contains('Python')])
# Out:
# 29

# %%
udemy_courses.dtypes
# Out:
# course_id               int64
# course_title           object
# is_paid                  bool
# price                  object
# num_subscribers         int64
# num_reviews             int64
# num_lectures            int64
# level                  object
# content_duration       object
# published_timestamp    object
# subject                object
# dtype: object

# %%
udemy_courses['published_timestamp']
# Out:
# 0       2014-09-18T05:07:05Z
# 1       2017-04-12T19:06:34Z
# 2       2017-04-26T18:34:57Z
# 3       2017-02-21T23:48:18Z
# 4       2017-02-21T23:44:49Z
#                 ...
# 3677    2015-04-20T22:15:17Z
# 3678    2015-10-26T20:04:21Z
# 3679    2015-11-11T18:55:45Z
# 3680    2017-05-26T16:45:55Z
# 3681    2016-09-26T22:19:48Z
# Name: published_timestamp, Length: 3682, dtype: object

# %%
udemy_courses['published_timestamp']=pd.to_datetime(udemy_courses['published_timestamp'])

# %%
udemy_courses['Year']=udemy_courses['published_timestamp'].dt

# %%
udemy_courses['yr']= udemy_courses['published_timestamp'].dt.year

# %%
udemy_courses['Year']==2017
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3677    False
# 3678    False
# 3679    False
# 3680    False
# 3681    False
# Name: Year, Length: 3682, dtype: bool

# %%
udemy_courses[udemy_courses.Year == 2017]
# Out:
# Empty DataFrame
# Columns: [course_id, course_title, is_paid, price, num_subscribers, num_reviews, num_lectures, level, content_duration, published_timestamp, subject, Year, yr]
# Index: []

# %%
udemy_courses.head(1)

# %%
udemy_courses.level.unique()

# %%
udemy_courses.groupby('level')['num_subscribers'].max()

# %%
udemy_courses.groupby('level').max()
